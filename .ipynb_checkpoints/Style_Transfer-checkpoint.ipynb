# %%
import numpy as np
import scipy.io
import scipy.misc
import tensorflow as tf

import matplotlib.pyplot as plt
import vgg19

from PIL import Image
from matplotlib.pyplot import imshow

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %% [markdown]
# # Loading Images #
#
# I chose a random golden gate bridge image, 'content.jpg'. I used that impressionist's painting, 'style.jpg'.

# %%
DIMS = [300,500]
style_image = scipy.misc.imresize(scipy.misc.imread('style.jpg'), DIMS)
plt.figure()
imshow(style_image)
content_image = scipy.misc.imresize(scipy.misc.imread('content.jpg'), DIMS)
plt.figure()
imshow(content_image)

# %%
VGG_MEAN = [103.939, 116.779, 123.68]
data_dict = np.load('vgg19.npy', encoding='latin1').item()
# Out:
# /Users/hongshuhong/Desktop/Computer-Science/Style Transfer/tensorflow-vgg-master/vgg19.npy
# npy file loaded

# %% [markdown]
# # Style Transfer #
#
# The style transfer paper:
#
# $L_{total}(p,a,x) = \alpha L_{content}(p,x) + \beta L_{style}(a,x) = \alpha (\frac{1}{2}\sum_{i,j}(P_{ij}^l-F_{ij}^l)^2)) + \beta (\sum_lw_lE_l)$

# %%
# We only choose the last few for content, as per Gatys et al.
CONTENT_LAYERS = ('relu4_2', 'relu5_2') 
# Style is created as a per-layer texture map. We use gram matrix here but there's also one on markov.
STYLE_LAYERS = ('relu1_1', 'relu2_1', 'relu3_1', 'relu4_1', 'relu5_1') 

def build_graph(CONTENT_LAYERS, STYLE_LAYERS):
